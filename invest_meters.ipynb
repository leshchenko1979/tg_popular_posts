# %% [markdown]
# # Подсчет статистики для Инвест-мэтров

# %%
import load_env

# %%
import datetime as dt
import logging
import os
from collections import namedtuple

import pandas as pd
import supabase
from tqdm.auto import tqdm

import supabasefs
from scanner import Scanner

logging.getLogger("pyrogram").setLevel("ERROR")
logging.getLogger("urllib3").setLevel("ERROR")
# Out:
# 2023-04-30 17:35:52,434:INFO - Using TgCrypto

# %%
LIMIT_HISTORY = dt.timedelta(days=30)  # насколько лезть вглубь чата

# %%
client = supabase.create_client(os.environ["SUPABASE_URL"], os.environ["SUPABASE_KEY"])
fs = supabasefs.SupabaseTableFileSystem(client, "sessions")
scanner = Scanner(fs=fs, chat_cache=False)

# %% [markdown]
# ## Взять список каналов

# %%
channels = {"@bekirovdanil", "@flipping_invest", "@atsogoev", "@ligainvestblog", "@d_smirnovv", "@thebestinvestru", "@na_remonte", "primetr_ru"}

# %% [markdown]
# ## Взять статистику по каждому каналу

# %%
Msg = namedtuple("Message", "username link reach reactions")


async def collect_stats(channel) -> int:
    msgs = []

    async for msg in scanner.get_chat_history(
        channel, min_date=dt.datetime.now() - LIMIT_HISTORY
    ):
        reactions = (
            (
                sum(reaction.count for reaction in msg.reactions.reactions)
                if msg.reactions
                else 0
            )
            + (msg.forwards or 0)
            + await scanner.get_discussion_replies_count(channel, msg.id)
        )
        msgs.append(
            Msg(
                username=channel,
                link=msg.link,
                reach=msg.views or 0,
                reactions=reactions,
            )
        )

    return msgs

# %%
results = []

with tqdm(total=len(channels)) as pbar:
    async with scanner.session(pbar):
        for channel in channels:
            pbar.set_postfix_str(channel)
            results.extend(await collect_stats(channel))
            pbar.update()

        # tasks = [asyncio.create_task(collect_stats(channel)) for channel in channels]
        # for finished_task in asyncio.as_completed(tasks):
            # results.extend(await finished_task)
            # pbar.update()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# ## Посчитать голоса и взносы

# %%
def calc_stats(msgs: pd.DataFrame):
    stats = msgs.groupby("username").agg({"reach": "mean"})
    stats["reach_percent_of_mean"] = stats["reach"] / stats["reach"].mean() * 100
    stats["votes"] = stats.reach / stats.reach.sum() * 100
    msgs["popularity"] = msgs.reactions / msgs.reach
    most_popular_idx = msgs.groupby("username").popularity.idxmax()
    most_popular = msgs.iloc[most_popular_idx].set_index("username")
    stats["post_for_digest"] = most_popular.link
    stats["post_for_digest_popularity"] = most_popular.popularity
    for col in ["reach", "reach_percent_of_mean", "votes"]:
        stats[col] = pd.to_numeric(stats[col].round(), downcast="integer")

    return stats.sort_values("reach", ascending=False).reset_index()

# %%
msgs = pd.DataFrame(results)
stats = calc_stats(msgs)
stats.to_clipboard()
stats
# Out:
#            username  reach  reach_percent_of_mean  votes  \
# 0         @atsogoev   2000                    193     24
# 1       @na_remonte   1892                    183     23
# 2       @d_smirnovv   1220                    118     15
# 3  @flipping_invest   1147                    111     14
# 4   @ligainvestblog    968                     94     12
# 5        primetr_ru    440                     43      5
# 6     @bekirovdanil    321                     31      4
# 7  @thebestinvestru    286                     28      3
#
#                     post_for_digest  post_for_digest_popularity
# 0        https://t.me/atsogoev/4033                    0.079511
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[63], line 3
#       1 new_channel = "@za_lubuyu_nedvizhku"
#       2 async with scanner.session():
# ----> 3     new_channel_msg = await collect_stats(new_channel)
#       4 new_channel_stats = calc_stats(new_channel_msg)
#       5 new_channel_stats
#
# Cell In[58], line 17, in collect_stats(channel)
#       5 msgs = []
#       7 async for msg in scanner.get_chat_history(
#       8     channel, min_date=dt.datetime.now() - LIMIT_HISTORY
#       9 ):
#      10     reactions = (
#      11         (
#      12             sum(reaction.count for reaction in msg.reactions.reactions)
#      13             if msg.reactions
#      14             else 0
#      15         )
#      16         + (msg.forwards or 0)
# ---> 17         + await scanner.get_discussion_replies_count(channel, msg.id)
#      18     )
#      19     msgs.append(
#      20         Msg(
#      21             username=channel,
#    (...)
#      25         )
#      26     )
#      28 return msgs
#
# File c:\Users\leshc\flipio\weekly\scanner.py:71, in Scanner.get_discussion_replies_count(self, chat_id, msg_id)
#      69 async def get_discussion_replies_count(self, chat_id, msg_id) -> int:
#      70     try:
# ---> 71         return await self.process_command(
#      72             "get_discussion_replies_count", chat_id, msg_id
#      73         )
#      74     except pyrogram.errors.MsgIdInvalid:
#      75         return 0
#
# File c:\Users\leshc\flipio\weekly\scanner.py:100, in Scanner.process_command(self, method, *args)
#      98 while True:
#      99     async with self.get_acc() as acc:
# --> 100         return await getattr(acc.app, method)(*args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyrogram\methods\messages\get_discussion_replies_count.py:50, in GetDiscussionRepliesCount.get_discussion_replies_count(self, chat_id, message_id)
#      26 async def get_discussion_replies_count(
#      27     self: "pyrogram.Client",
#      28     chat_id: Union[int, str],
#      29     message_id: int,
#      30 ) -> int:
#      31     """Get the total count of replies in a discussion thread.
#      32
#      33     .. include:: /_includes/usable-by/users.rst
#    (...)
#      45             count = await app.get_discussion_replies_count(chat_id, message_id)
#      46     """
#      48     r = await self.invoke(
#      49         raw.functions.messages.GetReplies(
# ---> 50             peer=await self.resolve_peer(chat_id),
#      51             msg_id=message_id,
#      52             offset_id=0,
#      53             offset_date=0,
#      54             add_offset=0,
#      55             limit=1,
#      56             max_id=0,
#      57             min_id=0,
#      58             hash=0
#      59         )
#      60     )
#      62     return r.count
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyrogram\methods\advanced\resolve_peer.py:59, in ResolvePeer.resolve_peer(self, peer_id)
#      36 """Get the InputPeer of a known peer id.
#      37 Useful whenever an InputPeer type is required.
#      38
#    (...)
#      56     KeyError: In case the peer doesn't exist in the internal database.
#      57 """
#      58 if not self.is_connected:
# ---> 59     raise ConnectionError("Client has not been started yet")
#      61 try:
#      62     return await self.storage.get_peer_by_id(peer_id)
#
# ConnectionError: Client has not been started yet

# %%
new_channel_depo = total_reach / new_channel_stats.iloc[0].reach * 1000 
new_channel_depo
# Out:
# 10391.364902506964

# %%
new_channel_depo = total_reach * 2
new_channel_depo
# Out:
# 14922
